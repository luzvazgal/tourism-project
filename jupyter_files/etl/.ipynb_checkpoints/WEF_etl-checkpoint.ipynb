# %% [markdown]
# # World Economic Forum data ETL

# %% [markdown]
# World Economic Forum Transform (Cleaning) process and Loading into Mongo DB

# %%
import pandas as pd

# %%
wef_path_2019 = "../../data/wef_data/WEF_2019.xlsx"
wef_path_2017 = "../../data/wef_data/WEF_2017.xlsx"
wef_path_2015 = "../../data/wef_data/WEF_2015.xlsx"

# %%
wef_df = pd.read_excel(wef_path_2019, header=3)
#wef_df_2017 = pd.read_excel(wef_path_2017, header=2)
#wef_df_2015 = pd.read_excel(wef_path_2015, header=3, sheet_name=1)

# %%
wef_df.head(5)
# Out:
#   Unnamed: 0  Placement Freeze date                    Dataset  Edition  \
# 0       HARD          1  03/09/2019  T&T Competitiveness Index     2019
# 1       HARD          1  03/09/2019  T&T Competitiveness Index     2019
# 2       HARD          1  03/09/2019  T&T Competitiveness Index     2019
# 3       HARD          1  03/09/2019  T&T Competitiveness Index     2019
# 4       HARD          1  03/09/2019  T&T Competitiveness Index     2019
#
#   GLOBAL ID  Code                                      Series  \
# 0       ITA  0.01  International tourist arrivals (thousands)
# 1       ITA  0.01  International tourist arrivals (thousands)
# 2       ITA  0.01  International tourist arrivals (thousands)
# 3       ITA  0.01  International tourist arrivals (thousands)
# 4       ITA  0.01  International tourist arrivals (thousands)
#
#                               Series indented         Attribute  ...  \
# 0  International tourist arrivals (thousands)  Date description  ...
# ...

# %%
wef_df = wef_df.loc[((wef_df['Series']=='Homicide cases/100,000 population') |
                              (wef_df['Series']=='Price competitiveness, 1-7 (best)')|
                              (wef_df['Series']=='Natural resources, 1-7 (best)')|
                              (wef_df['Series']=='Cultural resources and business travel, 1-7 (best)')|
                              (wef_df['Series']=='Index of terrorism incidence, 1-7')|
                              (wef_df['Series']=='Government prioritization of travel and tourism industry, 1-7')|
                              (wef_df['Series']=='Visa requirements')|
                               (wef_df['Series']=='Tourist service infrastructure, 1-7 (best)')) &
                             (wef_df['Attribute']=='Value')]
wef_df
# Out:
#      Unnamed: 0  Placement          Freeze date                    Dataset  \
# 152        HARD         20           03/09/2019  T&T Competitiveness Index
# 158        HARD         21           03/09/2019  T&T Competitiveness Index
# 302      SURVEY         45           03/09/2019  T&T Competitiveness Index
# 338        HARD         51           03/09/2019  T&T Competitiveness Index
# 662   AGGREGATE        104           03/09/2019  T&T Competitiveness Index
# 692   AGGREGATE        109           03/09/2019  T&T Competitiveness Index
# 704   AGGREGATE        111           03/09/2019  T&T Competitiveness Index
# 710   AGGREGATE        112           03/09/2019  T&T Competitiveness Index
# 863        HARD         20  2017-03-28 00:00:00  T&T Competitiveness Index
# 869        HARD         21  2017-03-28 00:00:00  T&T Competitiveness Index
# 1013     SURVEY         45  2017-03-28 00:00:00  T&T Competitiveness Index
# ...

# %% [markdown]
# ## Cleaning Data
#
# #### Remove unnecessary columns

# %%
deleted_columns = ['Unnamed: 0', 'Placement', 'Freeze date', 'Dataset',  'GLOBAL ID', 'Code', 
                   'Series indented',
                   'Sample average',
'Sub-Saharan Africa',
'Americas',
'Middle East and North Africa',
'Asia-Pacific',
'Europe and Eurasia ',
'North and Central America',
'South America',
'South Asia',
'Eastern Asia and Pacific',
'South-East Asia',
'Balkans and Eastern Europe',
'Eurasia',
'Northern Europe',
'Southern Europe',
'Western Europe',
'North Africa',
'Middle East',
'Western Africa',
'Eastern Africa',
'Southern Africa',
'Upper-middle-income',
'Lower-middle-income',
'High-income',
'Low-income', 'Attribute']

# %%
wef_df.drop(labels=deleted_columns, axis=1, inplace=True)

# %%
wef_df = wef_df.sort_values(by=['Edition', 'Series'])

# %%
wef_df.columns = wef_df.columns.str.replace('.', '', regex=False)

# %%
wef_df_2015 = wef_df.loc[wef_df['Edition']==2015]
wef_dict_2015 = wef_df_2015.drop(labels='Edition', axis=1).set_index(keys='Series').to_dict(orient='dict')

# %%
wef_df_2017 = wef_df.loc[wef_df['Edition']==2017]
wef_dict_2017 = wef_df_2017.drop(labels='Edition', axis=1).set_index(keys='Series').to_dict(orient='dict')

# %%
wef_df_2019 = wef_df.loc[wef_df['Edition']==2019]
wef_dict_2019 = wef_df_2019.drop(labels='Edition', axis=1).set_index(keys='Series').to_dict(orient='dict')

# %%
wef_dict_final = []

for country in wef_dict_2015.keys():
    dict_2015 = {'2015': wef_dict_2015[country]}
    dict_2017 = {'2017': wef_dict_2017[country]}
    dict_2019 = {'2019': wef_dict_2019[country]}
    
   
    wef_dict_final.append({country:[dict_2015, dict_2017, dict_2019]})
    #wef_dict_final.append({country: {{'2015': wef_dict_2015[country]}, 
                            #{'2017': wef_dict_2017[country]}, 
                                     #{'2019': wef_dict_2019[country]}} })
wef_dict_final
# Out:
# [{'Albania': [{'2015': {'Cultural resources and business travel, 1-7 (best)': 1.1412280977478004,
#      'Government prioritization of travel and tourism industry, 1-7': 4.200105320361137,
#      'Homicide cases/100,000 population': 5,
#      'Index of terrorism incidence, 1-7': 6.99,
#      'Natural resources, 1-7 (best)': 2.0340317844780884,
#      'Price competitiveness, 1-7 (best)': 4.376511671312588,
#      'Tourist service infrastructure, 1-7 (best)': 3.9411395007262757,
#      'Visa requirements': 22}},
#    {'2017': {'Cultural resources and business travel, 1-7 (best)': 1.1393623830439568,
#      'Government prioritization of travel and tourism industry, 1-7': 4.955409806329499,
#      'Homicide cases/100,000 population': 1283.6690089173449,
#      'Index of terrorism incidence, 1-7': 6.935506769807933,
#      'Natural resources, 1-7 (best)': 2.1887897370022382,
#      'Price competitiveness, 1-7 (best)': 4.704755339707931,
# ...

# %% [markdown]
# ## Insert into MongoDB

# %%
import pymongo

# %%
conn = 'mongodb+srv://user1:1234@cluster0.oi7pu.mongodb.net/turismo?retryWrites=true&w=majority'
client = pymongo.MongoClient(conn)
db = client['tourismDB']

# %%
WEF_collection = db['WEF']

# %%
#for wef in wef_dict:
WEF_collection.insert_many(wef_dict_final)
